# %% [markdown]
# # Create MOLA JSON
# version: 2
#
# info:
# - Create standard MOLA JSON
#
# author: nuno costa

# %% [markdown]
# ## MOLA Annotations Data Format

# %% [markdown]
# If you wish to combine multiple datasets, it is often useful to convert them into a unified data format.
#
# Conventions:

# %%
 #ANNOTATIONS FORMAT (BASED ON COCO)

 #Annotations format keys:

{ "info": None, 
"licenses": [], #TODO
"categories": [], #NOT ZERO-PADDED (from 1 to n) WARNING: Labelling in most algorithms is zero padded , be careful 
"images": [],
"annotations": [],
"videos": [], 
"video_annotations": [], #TODO
"tracks": [], #TODO - only for Object Tracking
"segment_info": [], #TODO
"datasets": [{'name': 'INCAR', 'id': 1}, {'name': 'INVICON', 'id': 2}] #NOT ZERO-PADDED (from 1 to n) 
}

#IMPORTANT: CONVENTION, no zero-padding, you need to implement the zero padding afterwards (most algorithms like yolo and mmaction2 need zero-padding)

#1 object definition:

info: {
 "year": int, 
 "version": str, 
 "description": str, 
 "contributor": str, 
 "url": str, 
 "date_created": datetime,
}

license: {
 "id": int, 
 "name": str, 
 "url": str,
}

category: {
 "id": int, 
 "name": str, 
 "supercategory": str,
 "dataset": int, #dataset_id
}

image: {
 "id" : int,
 "video_id": int, 
 "file_name" : str,
 "license" : int,
 "dataset": int, #dataset_id
 # Redundant fields for COCO-compatibility
 "width": int,
 "height": int,
 "frame_index": int, #frame index from original video_id
 "date_captured": datetime,
}

annotation: { #rawframes annotation
 "category_id": int
 "image_id": int,
 #"track_id": int, # NOT FOR ACTION, ONLY FOR OBJECT TRACKING
 "bbox": [x,y,width,height],
 "area": float,
 "dataset": int, #dataset_id
 # Redundant field for compatibility with COCO scripts
 "id": int,
 "iscrowd": 0 or 1,  (iscrowd=1) are used to label large groups of objects (e.g. a crowd of people)
 "segmentation": RLE(iscrowd=1) or [polygon](iscrowd=0), 

}

video: { 
 "id": int,
 "name": str,
 "width" : int,
 "height" : int,
 "total_frames": int, # TOTAL NUMBER OF FRAMES OF THE VIDEO
 "fps": int,
 "dataset": int, #dataset_id
 #"metadata": dict,  # Metadata about the video - NOT NECESSARY ADDITIONAL DICT
}

video_annotation: { #TODO
 "id": int,
 "category_id": int, #label
 "video_id": int,
 "frame_start": int, #in frames, then it can be converted using the fps
 "frame_end":int, #in frames
 "label_frames": int, # TOTAL NUMBER OF FRAMES OF LABEL category_id
 "dataset": int, #dataset_id
}



segment: { #TODO
 "id": int, 
 "category_id": int, 
 "area": int, 
 "bbox": [x,y,width,height], 
 # Redundant field for compatibility with COCO scripts
 "iscrowd": 0 or 1,
}


track: { #DOES IT MAKE SENSE TO TRACT ACTIONS INSIDE THE VIDEO? NO- ONLY OBJECTS
 "id": int,
 "category_id": int,
 "video_id": int
}

# %% [markdown]
# ## SETUP

# %%
from annotate_v5 import *
import platform 
import json
import os
import sys
from itertools import groupby

# %%
#Define root dir dependent on OS
rdir=os.getcwd()+'/examples/' #WARNING needs to be root datasets 
print('OS: {}'.format(platform.platform()))
if str(platform.platform()).upper().find('linux'.upper())>-1: rdir=rdir #"/mnt/Data-Ext/Datasets/Internal Datasets/EASYRIDE/P19/" #'/mnt/d/external_datasets/'
print('root dir: {}'.format(rdir))
print('OS separator: {}'.format(os.path.sep))
# Out:
# OS: Linux-5.13.0-30-generic-x86_64-with-glibc2.10
# root dir: /mnt/Data/Algorithms/MOLA/NC/molannotate/examples/
# OS separator: /

# %% [markdown]
# # SINGLE CASE STUDY (Function defenition - Obligatory!!)

# %% [markdown]
# ### INIT motionLAB JSON
# - uses annotate.init_json() function

# %%
res={
    'rgb': [2048, 1536], #w,h
    'thermal': [640,512],
    'pointcloud': [640,576],
    'nvs':[1280,800],
    'opticalflow':[2048,1536],
    'fps': 30
}

# %%
def init_json(file='mola.json'):
    output = {
        "info": None,
        "licenses": [],
        "categories": [],
        "videos": [],
        "images": [],
        "tracks": [],
        "segment_info": [],
        "annotations": [],
        "video_annotations": [],
        "datasets": [] #[{'name': 'COCO', 'id': 1}, {'name': 'TAO', 'id': 2}] #Not zero-padded
    }
    output['info'] = {
        "description": "MOLA Dataset",
        "url": "",
        "version": "1",
        "year": 2021,
        "date_created": datetime.datetime.utcnow().isoformat(' ')
    }

    with open(file, 'w') as f:
        json.dump(output, f)
    print("JSON INITIATED : {}".format(file))

# %%
molafile=rdir+'INCAR/'+'mola.json'
init_json(file=molafile)
molajson =  json.load(open(molafile))
molajson['datasets']=[{'name': 'INCAR', 'id': 1}]
with open(molafile, 'w') as f:
    json.dump(molajson, f)
for k in molajson:
    print(k, len(molajson[k]))
# Out:
# JSON INITIATED : /mnt/Data/Algorithms/MOLA/NC/molannotate/examples/INCAR/mola.json
# info 5
# licenses 0
# categories 0
# videos 0
# images 0
# tracks 0
# segment_info 0
# annotations 0
# video_annotations 0
# datasets 1

# %% [markdown]
# ### IMPORT JSON LABELS

# %%
file=rdir+"INCAR/20210506/Session 1/C8_P6_P5_1/gt.json"
gt=json.load(open(file)) #update to meet your needs
molaexample = json.load(open(rdir+'molaexample.json')) #EXAMPLES

# %%
def parse_path(path):
    parsed_path = path.replace('\\', '/')
    parsed_path = parsed_path.replace('\ ', '/')
    return parsed_path

# %%
def fix_pahts(gt, remove_gt=True, dataset_root="INCAR", replace_sensor=None):
    """
    replace_sensor=["nvs_push", "rgb"] or NONE to not replace
    """
    #fix gt datasource
    paths=gt['gTruth']['DataSource']
    if isinstance(paths, dict) and 'Source' in paths: paths=paths['Source']
    paths=[parse_path(p) for p in paths]
    #remove MATLAB BUG: 'C:\\Tools\\MATLAB\\R2020a\\examples\\symbolic\\data\\196.png'
    originalpath=paths[0]
    for p in paths: #verify it is not a matlab path the first one
        if not p.find("MATLAB") >-1 : 
            originalpath=p
            break
    originalpath=parse_path(originalpath) 
    paths = ['/'.join(originalpath.split('/')[:-1]+[p.split('/')[-1]]) if p.find("MATLAB") > -1 else p for p in paths]  
    #remove root dir 
    paths = ['/'.join(p.split('/')[p.split('/').index(dataset_root):]) for p in paths] 
    #remove gt dir
    if remove_gt: paths = [p.replace("/gt/","/") if p.find('/gt/')>-1 else p for p in paths]
    if replace_sensor:
        print(replace_sensor)
        paths = [p.replace(replace_sensor[0], replace_sensor[1])for p in paths] 
    gt['gTruth']['DataSource']=paths
    return gt
fix_pahts(gt, replace_sensor=["rgb","opticalflow"])
# Out:
# ['rgb', 'opticalflow']
# {'gTruth': {'DataSource': ['INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow
png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/370.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/371.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/372.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/373.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/374.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/375.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/376.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/377.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/378.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/379.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/380.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/381.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/382.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/383.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/384.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/385.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/386.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/387.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/388.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/389.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/390.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/391.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/392.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/393.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/394.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/395.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/396.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/397.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/398.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/399.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/400.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/401.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/402.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/403.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/404.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/405.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/406.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/407.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/408.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/409.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/410.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/411.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/412.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/413.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/414.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/415.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/416.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/417.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/418.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/419.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/420.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/421.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/422.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/423.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/424.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/425.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/426.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/427.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/428.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/429.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/430.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/431.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/432.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/433.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/434.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/435.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/436.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/437.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/438.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/439.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/440.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/441.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/442.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/443.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/444.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/445.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/446.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/447.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/448.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/449.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/450.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/451.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/452.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/453.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/454.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/455.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/456.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/457.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/458.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/459.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/460.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/461.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/462.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/463.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/464.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/465.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/466.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/467.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/468.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/469.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/470.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/471.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/472.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/473.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/474.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/475.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/476.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/477.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/478.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/479.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/480.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/481.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/482.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/483.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/484.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/485.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/486.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/487.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/488.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/489.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/490.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/491.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/492.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/493.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/494.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/495.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/496.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/497.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/498.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/499.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/500.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/501.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/502.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/503.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/504.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/505.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/506.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/507.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/508.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/509.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/510.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/511.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/512.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/513.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/514.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/515.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/516.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/517.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/518.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/519.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/520.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/521.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/522.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/523.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/524.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/525.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/526.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/527.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/528.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/529.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/530.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/531.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/532.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/533.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/534.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/535.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/536.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/537.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/538.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/539.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/540.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/541.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/542.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/543.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/544.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/545.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/546.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/547.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/548.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/549.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/550.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/551.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/552.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/553.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/554.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/555.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/556.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/557.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/558.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/559.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/560.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/561.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/562.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/563.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/564.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/565.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/566.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/567.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/568.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/569.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/570.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/571.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/572.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/573.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/574.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/575.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/576.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/577.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/578.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/579.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/580.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/581.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/582.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/583.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/584.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/585.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/586.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/587.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/588.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/589.png',
#    'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/590.png'],
#   'LabelDefinitions': [{'Name': 'VIOLENT',
#     'Type': 'Scene',
#     'LabelColor': [0, 0.7241, 0.6552],
#     'Group': 'None',
#     'Description': ''}],
#   'LabelData': [{'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': False},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True},
#    {'VIOLENT': True}]}}

# %% [markdown]
# #### CATEGORIES IMPORT

# %%
#EXAMPLE
display(molaexample["categories"][0])
# Out:
# {'name': 'VIOLENT', 'id': 1, 'dataset': 1}

# %%
gt['gTruth']['LabelDefinitions']
# Out:
# [{'Name': 'VIOLENT',
#   'Type': 'Scene',
#   'LabelColor': [0, 0.7241, 0.6552],
#   'Group': 'None',
#   'Description': ''}]

# %%
def import_categories(molajson, gt, start_id=0):
    dataset=molajson["datasets"][0]['id']
    # IMPORT categories name and id
    cat_l=[]
    cat_l_id=[]
    cat_l_dset=[]
    cat=gt['gTruth']['LabelDefinitions']#change to meet your needs
    for i,c in enumerate(tqdm(cat)):
        cat_l.append(c['Name'])
        cat_l_id.append(start_id+i+1) # id start from 1
        cat_l_dset.append(dataset) # dataset index
        molajson['categories'].append({'name':cat_l[i],'id':cat_l_id[i],'dataset':cat_l_dset[i]})
    # ADDITIONAL CATEGORIES: MANUAL
    name='NONVIOLENT'
    cid=len(cat_l)+1
    molajson['categories'].append({'name':name,'id':cid,'dataset':dataset})
    cat_l.append(name)
    cat_l_id.append(cid)
    cat_l_dset.append(dataset)
    print("\n>> categories:\n", molajson['categories'][-2:])
    return molajson, cat_l, cat_l_id, cat_l_dset
molajson, cat_l, cat_l_id, cat_l_dset=import_categories(molajson, gt)
# Out:
# 100%|████████████████| 1/1 [00:00<00:00, 9098.27it/s]
# >> categories:
#  [{'name': 'VIOLENT', 'id': 1, 'dataset': 1}, {'name': 'NONVIOLENT', 'id': 2, 'dataset': 1}]

# %% [markdown]
# #### VIDEO IMPORT

# %%
def import_videos(molajson, gt, res, start_id=0, sensor="rgb", ext=".mp4"):
    dataset=molajson["datasets"][0]['id']
    #single-level:
    vid=start_id+1
    video_l=[]
    video_l_id=[]
    total_frames=len(gt['gTruth']['DataSource'])
    #INCAR/20210521/Session 2/C9_P4_P3_2/rgb
    videon='_'.join(gt['gTruth']['DataSource'][0].split('/')[:4])+'_'+sensor+ext #f'video_{vid}_{sensor}{ext}' 
    videon=videon.replace(' ','_') # remove trailing spaces in "Session 1"
    video='/'.join(gt['gTruth']['DataSource'][0].split('/')[:4])+'/'+videon
    video_l.append(video)
    video_l_id.append(vid)
    i=0 #no loop
    molajson['videos'].append({'name':video_l[i],
                               'id':video_l_id[i],
                               'width': res[sensor][0],
                               'height': res[sensor][1],
                               'sensor': sensor,
                               'fps': res['fps'],
                               'total_frames': total_frames,
                               'dataset':dataset})
    print("\n>> video:\n", molajson['videos'][-2:])
    return molajson, video_l, video_l_id
molajson, video_l, video_l_id=import_videos(molajson, gt, res)
# Out:
# >> video:
#  [{'name': 'INCAR/20210506/Session 1/C8_P6_P5_1/INCAR_20210506_Session_1_C8_P6_P5_1_rgb.mp4', 'id': 1, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 590, 'dataset': 1}]

# %% [markdown]
# #### IMAGE IMPORT

# %%
#EXAMPLE
display(molaexample["images"][0])
# Out:
# {'file_name': 'INCAR/20210506/Session 1/C8_P6_P5_1/gt/rgb/1.png',
#  'id': 1,
#  'video_id': 1,
#  'caption': 'C8_P6_P5_1',
#  'width': 2048,
#  'height': 1536,
#  'frame_index': 1,
#  'date_captured': '20210506',
#  'dataset': 1}

# %%
gt['gTruth']['DataSource'][0]
# Out:
# 'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/1.png'

# %%
def import_images(molajson, gt, res, start_id=0, video_id=1, sensor="rgb"):
    dataset=molajson["datasets"][0]['id']
    # images filepath and id
    img_l=[]
    img_l_id=[]
    img=gt['gTruth']['DataSource']
    for i,im in enumerate(tqdm(img)):
        img_l.append(im)
        img_l_id.append(start_id+i+1) # id start from 1
        frame_index=img_l[i].split('/')[-1]
        frame_index=int(frame_index.split('.')[0])
        molajson['images'].append({'file_name':img_l[i],
                                   'id':img_l_id[i],
                                   'video_id':video_id,
                                   'caption':img_l[i].split('/')[-4], # scenario
                                   'width': res[sensor][0],
                                   'height': res[sensor][1],
                                   "frame_index": frame_index,
                                   "date_captured": img_l[i].split('/')[-6],
                                   'dataset':dataset})
    print("\n>> images:\n", molajson['images'][-2:])
    return molajson, img_l, img_l_id
molajson, img_l, img_l_id=import_images(molajson, gt, res, video_id=video_l_id[-1])
# Out:
# 100%|██████████| 590/590 [00:00<00:00, 310611.19it/s]
# >> images:
#  [{'file_name': 'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/589.png', 'id': 589, 'video_id': 1, 'caption': 'Session 1', 'width': 2048, 'height': 1536, 'frame_index': 589, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210506/Session 1/C8_P6_P5_1/opticalflow/590.png', 'id': 590, 'video_id': 1, 'caption': 'Session 1', 'width': 2048, 'height': 1536, 'frame_index': 590, 'date_captured': 'INCAR', 'dataset': 1}]

# %% [markdown]
# #### CREATE ANNOTATIONS

# %%
#EXAMPLE
display(molaexample["annotations"][1000])
# Out:
# {'id': 413,
#  'category_id': 1,
#  'image_id': 1001,
#  'bbox': [0, 0, 2048, 1536],
#  'area': 3145728,
#  'label_frames': 267,
#  'iscrowd': 0,
#  'dataset': 1}

# %%
gt['gTruth']['LabelData'][0]
# Out:
# {'VIOLENT': False}

# %%
def create_annotations(molajson, gt, res, cat_l, cat_l_id, cat_l_dset, img_l_id, start_id=0, sensor="rgb"):
    dataset=molajson["datasets"][0]['id']
    # annotations category_id, image_id, bbox, and dataset
    ann_id=[]
    ann_catid=[]
    ann_imgid=[]
    ann_bbox=[]
    ann_dset=[]
    labels=gt['gTruth']['LabelData']
    for i,l in enumerate(tqdm(labels)):
        annid=start_id+i+1
        current_label=list(l.keys())[0]
        if current_label=='VIOLENT' and not l["VIOLENT"]: current_label="NONVIOLENT" #specific rule of gt labelling
        catidx=cat_l.index(current_label)
        catid=cat_l_id[catidx]
        imgidx=i #frame
        imgid=img_l_id[imgidx]
        bbox=[0, 0, res[sensor][0], res[sensor][1]] # [x,y,width,height], #default RGB
        area=res[sensor][0]*res[sensor][1] #default RGB
        ann_id.append(annid)
        ann_catid.append(catid)
        ann_imgid.append(imgid)
        ann_bbox.append(bbox)
        ann_dset.append(dataset)
        molajson['annotations'].append({'id':annid,
                                        'category_id':catid,
                                        'image_id':imgid,
                                        'bbox': bbox,
                                        'area': area,
                                        'iscrowd': 0,
                                        'dataset':dataset})
    print("\n>> annotations:\n", molajson['annotations'][-2:])
    return molajson, ann_id, ann_catid, ann_imgid, ann_bbox, ann_dset
molajson, ann_id, ann_catid, ann_imgid, ann_bbox, ann_dset=create_annotations(molajson, gt,res, cat_l, cat_l_id, cat_l_dset, img_l_id)
# Out:
# 100%|██████████| 590/590 [00:00<00:00, 406144.65it/s]
# >> annotations:
#  [{'id': 589, 'category_id': 1, 'image_id': 589, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 590, 'category_id': 1, 'image_id': 590, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]

# %%
print("\n>> annotations:\n", molajson['annotations'][-5:])
# Out:
# >> annotations:
#  [{'id': 586, 'category_id': 1, 'image_id': 586, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 587, 'category_id': 1, 'image_id': 587, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 588, 'category_id': 1, 'image_id': 588, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 589, 'category_id': 1, 'image_id': 589, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 590, 'category_id': 1, 'image_id': 590, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]

# %%
def create_video_annotations(molajson, gt, res, cat_l, cat_l_id, cat_l_dset, video_l_id, start_id=0, sensor="rgb"):
    dataset=molajson["datasets"][0]['id']
    # annotations category_id, image_id, bbox, and dataset
    ann_id=[]
    ann_catid=[]
    ann_videoid=[]
    ann_dset=[]
    labels=gt['gTruth']['LabelData']
    #extract frames and correspondent labels
    labels_l=[]
    frames_l=[]
    previous_label=''
    frames_per_label=[]
    for i,l in enumerate(labels): #UNSPECIFIC LABEL EXTRACTOR
        current_label=list(l.keys())[0]
        if current_label=='VIOLENT' and not l["VIOLENT"]: current_label="NONVIOLENT" #specific rule of gt labelling
        if previous_label != current_label or i+1>=len(labels):
            if i+1>=len(labels): frames_per_label.append(i+1)
            if frames_per_label: frames_l.append(frames_per_label)
            if previous_label !='': labels_l.append(previous_label)
            previous_label=current_label
            frames_per_label=[]
        frames_per_label.append(i+1)
    #create video annotations
    for i,c in enumerate(labels_l):
        annid=start_id+i+1
        catidx=cat_l.index(c)
        label_frames=frames_l[i]
        if not label_frames: continue #no frames
        catid=cat_l_id[catidx] 
        videoidx=0 #only one video per scenario
        videoid=video_l_id[videoidx]
        ann_id.append(annid)
        ann_catid.append(catid)
        ann_videoid.append(videoid)
        ann_dset.append(dataset)
        molajson['video_annotations'].append({'id':annid,
                                        'category_id':catid,
                                        'video_id':videoid,
                                        'frame_start': int(label_frames[0]), #in frames, then it can be converted using the fps
                                        'frame_end': int(label_frames[-1]), #in frames
                                        "label_frames": len(label_frames),
                                        'dataset':dataset})
    print("\n>> video_annotations:\n", molajson['video_annotations'][-2:])
    """  
    frames_violent=[i+1 for i,l in enumerate(labels) if l["VIOLENT"]]
    frames_nonviolent=[i+1 for i,l in enumerate(labels) if not l["VIOLENT"]]
    for i,c in enumerate(tqdm(cat_l)):
        annid=start_id+i+1
        catidx=i
        #specific - TODO unspecific
        label_frames=frames_violent
        if c=="NONVIOLENT": label_frames=frames_nonviolent
        if not label_frames: continue #no frames of this category, therefore video of this category
        catid=cat_l_id[catidx]
        #dataset=cat_l_dset[catidx]
        videoidx=0 #only one video per scenario
        videoid=video_l_id[videoidx]
        ann_id.append(annid)
        ann_catid.append(catid)
        ann_videoid.append(videoid)
        ann_dset.append(dataset)
        molajson['video_annotations'].append({'id':annid,
                                        'category_id':catid,
                                        'video_id':videoid,
                                        'frame_start': int(label_frames[0]), #in frames, then it can be converted using the fps
                                        'frame_end': int(label_frames[-1]), #in frames
                                        "label_frames": len(label_frames),
                                        'dataset':dataset})
    print("\n>> video_annotations:\n", molajson['video_annotations'][-2:])"""
    return molajson, ann_id, ann_catid, ann_videoid, ann_dset
molajson, ann_id, ann_catid, ann_videoid, ann_dset=create_video_annotations(molajson, gt,res, cat_l, cat_l_id, cat_l_dset, video_l_id)
# Out:
# >> video_annotations:
#  [{'id': 1, 'category_id': 2, 'video_id': 1, 'frame_start': 1, 'frame_end': 358, 'label_frames': 358, 'dataset': 1}, {'id': 2, 'category_id': 1, 'video_id': 1, 'frame_start': 359, 'frame_end': 590, 'label_frames': 232, 'dataset': 1}]

# %% [markdown]
# #### Missings handler

# %%
def missings_handler(imgdir,sensor):
    gt = {'gTruth': {
        'DataSource': ['INCAR/20210521/Session 2/C9_P4_P3_2/rgb/1.png'],
        'LabelDefinitions': [{'Name': 'VIOLENT','Type': 'Scene','LabelColor': [0, 0.7241, 0.6552],'Group': 'None','Description': ''}],
        'LabelData': [{'VIOLENT': False}]}}
    DIR = os.path.join(imgdir,sensor)
    L_DIR = os.listdir(DIR)
    L_DIR = sorted(L_DIR, key=lambda x: int(os.path.splitext(x.split('/')[-1])[0]))
    frameslist=[name for name in L_DIR if os.path.isfile(os.path.join(DIR, name))]
    gt['gTruth']['DataSource']=[os.path.join(DIR, frame) for frame in frameslist]
    gt['gTruth']['LabelData']=[{'VIOLENT': False} for frame in frameslist]
        
    return gt
#gt=missings_handler('/mnt/Data-Ext/Datasets/Internal Datasets/EASYRIDE/P19/INCAR/20210422/Session1/C13_P7_P8_1','rgb')

# %% [markdown]
# # MULTI CASE STUDY (For loop script)

# %%
datasets=["INCAR"] #['INCAR', 'INVICON']
rdir= "/mnt/Data-Ext/Datasets/Internal Datasets/EASYRIDE/P19/" #rdir
# FOR LOOP"
datasetsdir = os.listdir(rdir)
missing_gt_json=[]
missing_gt_mat=[]
label_folder=""#"gt"
missings_handler_b=True #missings_handler()function - replace if using other categories
label_fname="gt.json"
label_mat_fname="gt.m"
sensor="opticalflow" #sensors or features: "rgb", "nvs", "thermal", "opticalflow" 
replace_sensor=["rgb", sensor] #replace gt label sensor; replace_sensor=["rgb", sensor] or NONE to not replace in the paths; if same 
ext=".mp4"
did=1 #start dataset id
for dataset in datasetsdir:
    if dataset in datasets:
        daysdir = os.path.join(rdir, dataset)
        if not os.path.isdir(daysdir): continue  # test if is a folder
        days = os.listdir(daysdir)
        print(">>>\n EXTRACTING DATASET: "+dataset)
        #INIT JSON
        molafile=rdir+dataset+'/'+'mola.json'
        init_json(file=molafile)
        molajson =  json.load(open(molafile))
        molajson['datasets'] = [{'name': dataset, 'id': did}] #[{'name': d, 'id': i+1} for i,d in enumerate(datasets)]
        did+=1 #nem dataset added
        with open(molafile, 'w') as f:
            json.dump(molajson, f)
        #INIT VARS
        imported_cats = False # import cats from each dataset
        cat_start_id = 0
        video_start_id = 0
        img_start_id = 0
        ann_start_id = 0
        vid_ann_start_id = 0
        cat_l, cat_l_id, cat_l_dset = [], [], []
        video_l, video_l_id = [], []
        img_l, img_l_id = [], []
        ann_id, ann_catid, ann_imgid, ann_bbox, ann_dset = [], [], [], [], []
        vid_ann_id, vid_ann_catid, ann_videoid, vid_ann_dset = [], [], [], []
        #FOR LOOP
        for day in days:
            sessiondir = os.path.join(daysdir, day)
            if not os.path.isdir(sessiondir): continue  # test if is a folder
            sessions = os.listdir(sessiondir)
            for session in sessions:
                scenariosdir = os.path.join(sessiondir, session)
                if not os.path.isdir(scenariosdir): continue  # test if is a folder
                scenarios = os.listdir(scenariosdir)
                for scenario in scenarios:
                    imgdir = os.path.join(scenariosdir, scenario)
                    if not os.path.isdir(imgdir): continue  # test if is a folder
                    labeldir = os.path.join(imgdir, label_folder)
                    # if not os.path.isdir(labeldir): continue #should exist
                    filename = os.path.join(labeldir, label_fname)
                    #TEST if sensor folder exists
                    sensorfolder = os.path.join(labeldir, sensor)
                    if not os.path.isdir(sensorfolder): continue 
                    try:
                        gt = json.load(open(filename))
                    except:
                        if missings_handler_b:
                            print("\n\n>>>>>>>CONVERTING MISSING  gtFILE: ", filename)
                            try:
                                gt = missings_handler(imgdir,sensor)
                                gt = fix_pahts(gt, dataset_root=dataset, replace_sensor=replace_sensor) #gTruth can be also missing missing
                                missing_gt_json.append([filename,"CONVERTED"])
                                if not os.path.isfile(filename.replace(label_fname, label_mat_fname)): missing_gt_mat.append(filename.replace(label_fname, label_mat_fname))
                            except Exception as e:
                                print(">>>>>>>MISSING: ", filename, e, sys.exc_info()[0])
                                missing_gt_json.append([filename,"FAIL_CONVERT"])
                                if not os.path.isfile(filename.replace(label_fname, label_mat_fname)): missing_gt_mat.append(filename.replace(label_fname, label_mat_fname))
                                continue
                        else:
                            print(">>>>>>>MISSING : ", filename)
                            missing_gt_json.append([filename,"MISSING"])
                            if not os.path.isfile(filename.replace(label_fname, label_mat_fname)): missing_gt_mat.append(filename.replace(label_fname, label_mat_fname))
                            continue
                    #Fix paths
                    try:
                        gt = fix_pahts(gt, dataset_root=dataset, replace_sensor=replace_sensor) #gTruth can be also missing missing
                    except:
                        print(">>>>>>> BUG gtFILE: ", filename)
                        missing_gt_json.append([filename,"BUG in GT file"])
                        if not os.path.isfile(filename.replace(label_fname, label_mat_fname)): missing_gt_mat.append(filename.replace(label_fname, label_mat_fname))
                        continue
                    # update molajson
                    if not imported_cats:  # only imports one time
                        molajson, cat_l, cat_l_id, cat_l_dset = import_categories(molajson, gt, start_id=cat_start_id)
                        imported_cats = True        
                    molajson, video_l, video_l_id=import_videos(molajson, gt, res,
                                                                start_id=video_start_id,
                                                                sensor=sensor,
                                                                ext=ext)
                    molajson, img_l, img_l_id=import_images(molajson, gt, res, 
                                                            start_id=img_start_id,
                                                            sensor=sensor,
                                                            video_id=video_l_id[-1])
                    molajson, ann_id, ann_catid, ann_imgid, ann_bbox, ann_dset = create_annotations(molajson, gt, res,
                                                                                                    cat_l, cat_l_id,
                                                                                                    cat_l_dset, img_l_id,
                                                                                                    start_id=ann_start_id,
                                                                                                    sensor=sensor)
                    molajson, vid_ann_id, vid_ann_catid, ann_videoid, vid_ann_dset=create_video_annotations(molajson, gt,res, 
                                                                                                cat_l, cat_l_id, 
                                                                                                cat_l_dset, video_l_id,
                                                                                                start_id=vid_ann_start_id,
                                                                                                sensor=sensor)
                    # update start ids to the last id
                    try:                     
                        cat_start_id = cat_l_id[-1]
                        video_start_id = video_l_id[-1]
                        img_start_id = img_l_id[-1]
                        ann_start_id = ann_id[-1]
                        vid_ann_start_id = vid_ann_id[-1]
                    except Exception as e:
                        print(">>>>>>> BUG IDs: ", filename, e, sys.exc_info()[0])
                        missing_gt_json.append([filename,"BUG IDs, missing frames?", e])
                        continue


        # results
        for k in molajson:
            print(k, len(molajson[k]))

        # # Save
        print('\n >> SAVING...')
        jsonfile=molafile
        with open(jsonfile, 'w') as f:
            json.dump(molajson, f)
        with open(jsonfile.replace('.json', '_missing_gtmat.txt'),'w') as f:
            f.write(str(missing_gt_mat))
        with open(jsonfile.replace('.json', '_missing_gtjson.txt'),'w') as f:
            f.write(str(missing_gt_json))
        print("JSON SAVED : {} \n".format(jsonfile))

        #retest results and save log
        molajson =  json.load(open(molafile))
        loglist=[]
        for k in molajson:
            loglist.append(f"{k}: {len(molajson[k])}\n")
            print(loglist[-1])
        for k in molajson:
            loglist.append("\n\n")
            try:
                loglist.append(f'molajson[{k}][-1] : {molajson[k][-1]}')
            except:
                loglist.append(f'molajson[{k}][-1] : Not List!')
        with open(jsonfile.replace('.json', '_json_content.txt'),'w') as f:
            for line in loglist:
                f.write(line)
# Out:
# >>>
#  EXTRACTING DATASET: INCAR
# JSON INITIATED : /mnt/Data-Ext/Datasets/Internal Datasets/EASYRIDE/P19/INCAR/mola.json
# 100%|███████████████| 1/1 [00:00<00:00, 12052.60it/s]
# >> categories:
#  [{'name': 'VIOLENT', 'id': 1, 'dataset': 1}, {'name': 'NONVIOLENT', 'id': 2, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C10_P7_P8_1/INCAR_20210422_Sessipn1_C10_P7_P8_1_rgb.mp4', 'id': 1, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 580, 'dataset': 1}]
# 100%|██████████| 580/580 [00:00<00:00, 254999.61it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C10_P7_P8_1/rgb/579.png', 'id': 579, 'video_id': 1, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 579, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C10_P7_P8_1/rgb/580.png', 'id': 580, 'video_id': 1, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 580, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 580/580 [00:00<00:00, 331114.24it/s]
# >> annotations:
#  [{'id': 579, 'category_id': 1, 'image_id': 579, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 580, 'category_id': 1, 'image_id': 580, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 1, 'category_id': 2, 'video_id': 1, 'frame_start': 1, 'frame_end': 441, 'label_frames': 441, 'dataset': 1}, {'id': 2, 'category_id': 1, 'video_id': 1, 'frame_start': 442, 'frame_end': 580, 'label_frames': 139, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C10_P7_P8_1/INCAR_20210422_Sessipn1_C10_P7_P8_1_rgb.mp4', 'id': 1, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 580, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C10_P7_P8_2/INCAR_20210422_Sessipn1_C10_P7_P8_2_rgb.mp4', 'id': 2, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 585, 'dataset': 1}]
# 100%|██████████| 585/585 [00:00<00:00, 336210.99it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C10_P7_P8_2/rgb/584.png', 'id': 1164, 'video_id': 2, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 584, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C10_P7_P8_2/rgb/585.png', 'id': 1165, 'video_id': 2, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 585, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 585/585 [00:00<00:00, 268747.85it/s]
# >> annotations:
#  [{'id': 1164, 'category_id': 1, 'image_id': 1164, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 1165, 'category_id': 1, 'image_id': 1165, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 3, 'category_id': 2, 'video_id': 2, 'frame_start': 1, 'frame_end': 413, 'label_frames': 413, 'dataset': 1}, {'id': 4, 'category_id': 1, 'video_id': 2, 'frame_start': 414, 'frame_end': 585, 'label_frames': 172, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C10_P7_P8_2/INCAR_20210422_Sessipn1_C10_P7_P8_2_rgb.mp4', 'id': 2, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 585, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C10_P8_P7_1/INCAR_20210422_Sessipn1_C10_P8_P7_1_rgb.mp4', 'id': 3, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 585, 'dataset': 1}]
# 100%|██████████| 585/585 [00:00<00:00, 334423.86it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C10_P8_P7_1/rgb/584.png', 'id': 1749, 'video_id': 3, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 584, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C10_P8_P7_1/rgb/585.png', 'id': 1750, 'video_id': 3, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 585, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 585/585 [00:00<00:00, 387258.18it/s]
# >> annotations:
#  [{'id': 1749, 'category_id': 1, 'image_id': 1749, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 1750, 'category_id': 1, 'image_id': 1750, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 5, 'category_id': 2, 'video_id': 3, 'frame_start': 1, 'frame_end': 403, 'label_frames': 403, 'dataset': 1}, {'id': 6, 'category_id': 1, 'video_id': 3, 'frame_start': 404, 'frame_end': 585, 'label_frames': 182, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C10_P8_P7_1/INCAR_20210422_Sessipn1_C10_P8_P7_1_rgb.mp4', 'id': 3, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 585, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C10_P8_P7_2/INCAR_20210422_Sessipn1_C10_P8_P7_2_rgb.mp4', 'id': 4, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 575, 'dataset': 1}]
# 100%|██████████| 575/575 [00:00<00:00, 264820.99it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C10_P8_P7_2/rgb/574.png', 'id': 2324, 'video_id': 4, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 574, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C10_P8_P7_2/rgb/575.png', 'id': 2325, 'video_id': 4, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 575, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 575/575 [00:00<00:00, 479658.87it/s]
# >> annotations:
#  [{'id': 2324, 'category_id': 1, 'image_id': 2324, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 2325, 'category_id': 1, 'image_id': 2325, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 7, 'category_id': 2, 'video_id': 4, 'frame_start': 1, 'frame_end': 390, 'label_frames': 390, 'dataset': 1}, {'id': 8, 'category_id': 1, 'video_id': 4, 'frame_start': 391, 'frame_end': 575, 'label_frames': 185, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C10_P8_P7_2/INCAR_20210422_Sessipn1_C10_P8_P7_2_rgb.mp4', 'id': 4, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 575, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C11_P7_P8_1/INCAR_20210422_Sessipn1_C11_P7_P8_1_rgb.mp4', 'id': 5, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 583, 'dataset': 1}]
# 100%|██████████| 583/583 [00:00<00:00, 263329.66it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C11_P7_P8_1/rgb/582.png', 'id': 2907, 'video_id': 5, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 582, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C11_P7_P8_1/rgb/583.png', 'id': 2908, 'video_id': 5, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 583, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 583/583 [00:00<00:00, 619528.56it/s]
# >> annotations:
#  [{'id': 2907, 'category_id': 1, 'image_id': 2907, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 2908, 'category_id': 1, 'image_id': 2908, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 9, 'category_id': 2, 'video_id': 5, 'frame_start': 1, 'frame_end': 506, 'label_frames': 506, 'dataset': 1}, {'id': 10, 'category_id': 1, 'video_id': 5, 'frame_start': 507, 'frame_end': 583, 'label_frames': 77, 'dataset': 1}]
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C11_P7_P8_1/INCAR_20210422_Sessipn1_C11_P7_P8_1_rgb.mp4', 'id': 5, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 583, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C11_P7_P8_2/INCAR_20210422_Sessipn1_C11_P7_P8_2_rgb.mp4', 'id': 6, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 580, 'dataset': 1}]
# 100%|██████████| 580/580 [00:00<00:00, 259211.12it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C11_P7_P8_2/rgb/579.png', 'id': 3487, 'video_id': 6, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 579, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C11_P7_P8_2/rgb/580.png', 'id': 3488, 'video_id': 6, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 580, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 580/580 [00:00<00:00, 234702.97it/s]
# >> annotations:
#  [{'id': 3487, 'category_id': 1, 'image_id': 3487, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 3488, 'category_id': 1, 'image_id': 3488, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 11, 'category_id': 2, 'video_id': 6, 'frame_start': 1, 'frame_end': 465, 'label_frames': 465, 'dataset': 1}, {'id': 12, 'category_id': 1, 'video_id': 6, 'frame_start': 466, 'frame_end': 580, 'label_frames': 115, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C11_P7_P8_2/INCAR_20210422_Sessipn1_C11_P7_P8_2_rgb.mp4', 'id': 6, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 580, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C11_P8_P7_1/INCAR_20210422_Sessipn1_C11_P8_P7_1_rgb.mp4', 'id': 7, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 582, 'dataset': 1}]
# 100%|██████████| 582/582 [00:00<00:00, 235489.57it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C11_P8_P7_1/rgb/581.png', 'id': 4069, 'video_id': 7, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 581, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C11_P8_P7_1/rgb/582.png', 'id': 4070, 'video_id': 7, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 582, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 582/582 [00:00<00:00, 257770.32it/s]
# >> annotations:
#  [{'id': 4069, 'category_id': 1, 'image_id': 4069, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 4070, 'category_id': 1, 'image_id': 4070, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 13, 'category_id': 2, 'video_id': 7, 'frame_start': 1, 'frame_end': 504, 'label_frames': 504, 'dataset': 1}, {'id': 14, 'category_id': 1, 'video_id': 7, 'frame_start': 505, 'frame_end': 582, 'label_frames': 78, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C11_P8_P7_1/INCAR_20210422_Sessipn1_C11_P8_P7_1_rgb.mp4', 'id': 7, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 582, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C11_P8_P7_2/INCAR_20210422_Sessipn1_C11_P8_P7_2_rgb.mp4', 'id': 8, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 590, 'dataset': 1}]
# 100%|██████████| 590/590 [00:00<00:00, 343461.40it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C11_P8_P7_2/rgb/589.png', 'id': 4659, 'video_id': 8, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 589, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C11_P8_P7_2/rgb/590.png', 'id': 4660, 'video_id': 8, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 590, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 590/590 [00:00<00:00, 301969.42it/s]
# >> annotations:
#  [{'id': 4659, 'category_id': 1, 'image_id': 4659, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 4660, 'category_id': 1, 'image_id': 4660, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 15, 'category_id': 2, 'video_id': 8, 'frame_start': 1, 'frame_end': 463, 'label_frames': 463, 'dataset': 1}, {'id': 16, 'category_id': 1, 'video_id': 8, 'frame_start': 464, 'frame_end': 590, 'label_frames': 127, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C11_P8_P7_2/INCAR_20210422_Sessipn1_C11_P8_P7_2_rgb.mp4', 'id': 8, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 590, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C12_P7_P8_1/INCAR_20210422_Sessipn1_C12_P7_P8_1_rgb.mp4', 'id': 9, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 580, 'dataset': 1}]
# 100%|██████████| 580/580 [00:00<00:00, 249379.43it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C12_P7_P8_1/rgb/579.png', 'id': 5239, 'video_id': 9, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 579, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C12_P7_P8_1/rgb/580.png', 'id': 5240, 'video_id': 9, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 580, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 580/580 [00:00<00:00, 381839.01it/s]
# >> annotations:
#  [{'id': 5239, 'category_id': 1, 'image_id': 5239, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 5240, 'category_id': 1, 'image_id': 5240, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 17, 'category_id': 2, 'video_id': 9, 'frame_start': 1, 'frame_end': 464, 'label_frames': 464, 'dataset': 1}, {'id': 18, 'category_id': 1, 'video_id': 9, 'frame_start': 465, 'frame_end': 580, 'label_frames': 116, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C12_P7_P8_1/INCAR_20210422_Sessipn1_C12_P7_P8_1_rgb.mp4', 'id': 9, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 580, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C12_P7_P8_2/INCAR_20210422_Sessipn1_C12_P7_P8_2_rgb.mp4', 'id': 10, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 578, 'dataset': 1}]
# 100%|██████████| 578/578 [00:00<00:00, 247277.41it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C12_P7_P8_2/rgb/577.png', 'id': 5817, 'video_id': 10, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 577, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C12_P7_P8_2/rgb/578.png', 'id': 5818, 'video_id': 10, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 578, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 578/578 [00:00<00:00, 262115.66it/s]
# >> annotations:
#  [{'id': 5817, 'category_id': 2, 'image_id': 5817, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 5818, 'category_id': 2, 'image_id': 5818, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 20, 'category_id': 1, 'video_id': 10, 'frame_start': 305, 'frame_end': 536, 'label_frames': 232, 'dataset': 1}, {'id': 21, 'category_id': 2, 'video_id': 10, 'frame_start': 537, 'frame_end': 578, 'label_frames': 42, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C12_P7_P8_2/INCAR_20210422_Sessipn1_C12_P7_P8_2_rgb.mp4', 'id': 10, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 578, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C12_P8_P7_1/INCAR_20210422_Sessipn1_C12_P8_P7_1_rgb.mp4', 'id': 11, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 583, 'dataset': 1}]
# 100%|██████████| 583/583 [00:00<00:00, 343341.65it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C12_P8_P7_1/rgb/582.png', 'id': 6400, 'video_id': 11, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 582, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C17_P7_P8_1/INCAR_20210422_Sessipn1_C17_P7_P8_1_rgb.mp4', 'id': 29, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 441, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C17_P7_P8_2/INCAR_20210422_Sessipn1_C17_P7_P8_2_rgb.mp4', 'id': 30, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 441, 'dataset': 1}]
# 100%|██████████| 441/441 [00:00<00:00, 329653.91it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C17_P7_P8_2/rgb/440.png', 'id': 14911, 'video_id': 30, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 440, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C17_P7_P8_2/rgb/441.png', 'id': 14912, 'video_id': 30, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 441, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 441/441 [00:00<00:00, 428962.91it/s]
# >> annotations:
#  [{'id': 14911, 'category_id': 2, 'image_id': 14911, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 14912, 'category_id': 2, 'image_id': 14912, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 43, 'category_id': 2, 'video_id': 29, 'frame_start': 1, 'frame_end': 441, 'label_frames': 441, 'dataset': 1}, {'id': 44, 'category_id': 2, 'video_id': 30, 'frame_start': 1, 'frame_end': 441, 'label_frames': 441, 'dataset': 1}]
#
#
# >>>>>>>CONVERTING MISSING  gtFILE:  /mnt/Data-Ext/Datasets/Internal Datasets/EASYRIDE/P19/INCAR/20210422/Session1/C17_P8_P7_1/gt.json
#
# >> video:
#  [{'name': 'INCAR/20210422/Sessipn1/C17_P7_P8_2/INCAR_20210422_Sessipn1_C17_P7_P8_2_rgb.mp4', 'id': 30, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 441, 'dataset': 1}, {'name': 'INCAR/20210422/Sessipn1/C17_P8_P7_1/INCAR_20210422_Sessipn1_C17_P8_P7_1_rgb.mp4', 'id': 31, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 440, 'dataset': 1}]
# 100%|██████████| 440/440 [00:00<00:00, 324968.09it/s]
# >> images:
#  [{'file_name': 'INCAR/20210422/Sessipn1/C17_P8_P7_1/rgb/439.png', 'id': 15351, 'video_id': 31, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 439, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210422/Sessipn1/C17_P8_P7_1/rgb/440.png', 'id': 15352, 'video_id': 31, 'caption': 'Sessipn1', 'width': 2048, 'height': 1536, 'frame_index': 440, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 440/440 [00:00<00:00, 368141.58it/s]
# >> annotations:
#  [{'id': 15351, 'category_id': 2, 'image_id': 15351, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 15352, 'category_id': 2, 'image_id': 15352, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
# ...
# 100%|██████████| 546/546 [00:00<00:00, 373161.15it/s]
# >> annotations:
#  [{'id': 663269, 'category_id': 1, 'image_id': 663269, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 663270, 'category_id': 1, 'image_id': 663270, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2089, 'category_id': 2, 'video_id': 1265, 'frame_start': 1, 'frame_end': 256, 'label_frames': 256, 'dataset': 1}, {'id': 2090, 'category_id': 1, 'video_id': 1265, 'frame_start': 257, 'frame_end': 546, 'label_frames': 290, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C7_P3_P4_2/INCAR_20210521_Sessipn_2_C7_P3_P4_2_rgb.mp4', 'id': 1265, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 546, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_1/INCAR_20210521_Sessipn_2_C7_P4_P3_1_rgb.mp4', 'id': 1266, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 572, 'dataset': 1}]
# 100%|██████████| 572/572 [00:00<00:00, 297328.28it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_1/rgb/571.png', 'id': 663841, 'video_id': 1266, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 571, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_1/rgb/572.png', 'id': 663842, 'video_id': 1266, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 572, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 572/572 [00:00<00:00, 345847.18it/s]
# >> annotations:
#  [{'id': 663841, 'category_id': 1, 'image_id': 663841, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 663842, 'category_id': 1, 'image_id': 663842, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2091, 'category_id': 2, 'video_id': 1266, 'frame_start': 1, 'frame_end': 280, 'label_frames': 280, 'dataset': 1}, {'id': 2092, 'category_id': 1, 'video_id': 1266, 'frame_start': 281, 'frame_end': 572, 'label_frames': 292, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_1/INCAR_20210521_Sessipn_2_C7_P4_P3_1_rgb.mp4', 'id': 1266, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 572, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_2/INCAR_20210521_Sessipn_2_C7_P4_P3_2_rgb.mp4', 'id': 1267, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 578, 'dataset': 1}]
# 100%|██████████| 578/578 [00:00<00:00, 315336.59it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_2/rgb/577.png', 'id': 664419, 'video_id': 1267, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 577, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_2/rgb/578.png', 'id': 664420, 'video_id': 1267, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 578, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 578/578 [00:00<00:00, 385300.02it/s]
# >> annotations:
#  [{'id': 664419, 'category_id': 1, 'image_id': 664419, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 664420, 'category_id': 1, 'image_id': 664420, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2093, 'category_id': 2, 'video_id': 1267, 'frame_start': 1, 'frame_end': 341, 'label_frames': 341, 'dataset': 1}, {'id': 2094, 'category_id': 1, 'video_id': 1267, 'frame_start': 342, 'frame_end': 578, 'label_frames': 237, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C7_P4_P3_2/INCAR_20210521_Sessipn_2_C7_P4_P3_2_rgb.mp4', 'id': 1267, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 578, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_1/INCAR_20210521_Sessipn_2_C8_P3_P4_1_rgb.mp4', 'id': 1268, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 588, 'dataset': 1}]
# 100%|██████████| 588/588 [00:00<00:00, 258896.78it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_1/rgb/587.png', 'id': 665007, 'video_id': 1268, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 587, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_1/rgb/588.png', 'id': 665008, 'video_id': 1268, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 588, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 588/588 [00:00<00:00, 270511.22it/s]
# >> annotations:
#  [{'id': 665007, 'category_id': 1, 'image_id': 665007, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 665008, 'category_id': 1, 'image_id': 665008, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2095, 'category_id': 2, 'video_id': 1268, 'frame_start': 1, 'frame_end': 312, 'label_frames': 312, 'dataset': 1}, {'id': 2096, 'category_id': 1, 'video_id': 1268, 'frame_start': 313, 'frame_end': 588, 'label_frames': 276, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_1/INCAR_20210521_Sessipn_2_C8_P3_P4_1_rgb.mp4', 'id': 1268, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 588, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_2/INCAR_20210521_Sessipn_2_C8_P3_P4_2_rgb.mp4', 'id': 1269, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 572, 'dataset': 1}]
# 100%|██████████| 572/572 [00:00<00:00, 349729.14it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_2/rgb/571.png', 'id': 665579, 'video_id': 1269, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 571, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_2/rgb/572.png', 'id': 665580, 'video_id': 1269, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 572, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 572/572 [00:00<00:00, 388210.66it/s]
# >> annotations:
#  [{'id': 665579, 'category_id': 2, 'image_id': 665579, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 665580, 'category_id': 2, 'image_id': 665580, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2098, 'category_id': 1, 'video_id': 1269, 'frame_start': 293, 'frame_end': 534, 'label_frames': 242, 'dataset': 1}, {'id': 2099, 'category_id': 2, 'video_id': 1269, 'frame_start': 535, 'frame_end': 572, 'label_frames': 38, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C8_P3_P4_2/INCAR_20210521_Sessipn_2_C8_P3_P4_2_rgb.mp4', 'id': 1269, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 572, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_1/INCAR_20210521_Sessipn_2_C8_P4_P3_1_rgb.mp4', 'id': 1270, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 577, 'dataset': 1}]
# 100%|██████████| 577/577 [00:00<00:00, 335288.64it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_1/rgb/576.png', 'id': 666156, 'video_id': 1270, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 576, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_1/rgb/577.png', 'id': 666157, 'video_id': 1270, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 577, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 577/577 [00:00<00:00, 388087.46it/s]
# >> annotations:
#  [{'id': 666156, 'category_id': 1, 'image_id': 666156, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 666157, 'category_id': 1, 'image_id': 666157, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2100, 'category_id': 2, 'video_id': 1270, 'frame_start': 1, 'frame_end': 387, 'label_frames': 387, 'dataset': 1}, {'id': 2101, 'category_id': 1, 'video_id': 1270, 'frame_start': 388, 'frame_end': 577, 'label_frames': 190, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_1/INCAR_20210521_Sessipn_2_C8_P4_P3_1_rgb.mp4', 'id': 1270, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 577, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_2/INCAR_20210521_Sessipn_2_C8_P4_P3_2_rgb.mp4', 'id': 1271, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 566, 'dataset': 1}]
# 100%|██████████| 566/566 [00:00<00:00, 299215.54it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_2/rgb/565.png', 'id': 666722, 'video_id': 1271, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 565, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_2/rgb/566.png', 'id': 666723, 'video_id': 1271, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 566, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 566/566 [00:00<00:00, 378745.38it/s]
# >> annotations:
#  [{'id': 666722, 'category_id': 1, 'image_id': 666722, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 666723, 'category_id': 1, 'image_id': 666723, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2102, 'category_id': 2, 'video_id': 1271, 'frame_start': 1, 'frame_end': 388, 'label_frames': 388, 'dataset': 1}, {'id': 2103, 'category_id': 1, 'video_id': 1271, 'frame_start': 389, 'frame_end': 566, 'label_frames': 178, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C8_P4_P3_2/INCAR_20210521_Sessipn_2_C8_P4_P3_2_rgb.mp4', 'id': 1271, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 566, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_1/INCAR_20210521_Sessipn_2_C9_P3_P4_1_rgb.mp4', 'id': 1272, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 564, 'dataset': 1}]
# 100%|██████████| 564/564 [00:00<00:00, 340617.34it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_1/rgb/563.png', 'id': 667286, 'video_id': 1272, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 563, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_1/rgb/564.png', 'id': 667287, 'video_id': 1272, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 564, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 564/564 [00:00<00:00, 312082.78it/s]
# >> annotations:
#  [{'id': 667286, 'category_id': 1, 'image_id': 667286, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 667287, 'category_id': 1, 'image_id': 667287, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2104, 'category_id': 2, 'video_id': 1272, 'frame_start': 1, 'frame_end': 224, 'label_frames': 224, 'dataset': 1}, {'id': 2105, 'category_id': 1, 'video_id': 1272, 'frame_start': 225, 'frame_end': 564, 'label_frames': 340, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_1/INCAR_20210521_Sessipn_2_C9_P3_P4_1_rgb.mp4', 'id': 1272, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 564, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_2/INCAR_20210521_Sessipn_2_C9_P3_P4_2_rgb.mp4', 'id': 1273, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 573, 'dataset': 1}]
# 100%|██████████| 573/573 [00:00<00:00, 213972.24it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_2/rgb/572.png', 'id': 667859, 'video_id': 1273, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 572, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_2/rgb/573.png', 'id': 667860, 'video_id': 1273, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 573, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 573/573 [00:00<00:00, 350749.59it/s]
# >> annotations:
#  [{'id': 667859, 'category_id': 1, 'image_id': 667859, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 667860, 'category_id': 1, 'image_id': 667860, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2106, 'category_id': 2, 'video_id': 1273, 'frame_start': 1, 'frame_end': 192, 'label_frames': 192, 'dataset': 1}, {'id': 2107, 'category_id': 1, 'video_id': 1273, 'frame_start': 193, 'frame_end': 573, 'label_frames': 381, 'dataset': 1}]
#
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C9_P3_P4_2/INCAR_20210521_Sessipn_2_C9_P3_P4_2_rgb.mp4', 'id': 1273, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 573, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C9_P4_P3_1/INCAR_20210521_Sessipn_2_C9_P4_P3_1_rgb.mp4', 'id': 1274, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 566, 'dataset': 1}]
# 100%|██████████| 566/566 [00:00<00:00, 345909.38it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C9_P4_P3_1/rgb/565.png', 'id': 668425, 'video_id': 1274, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 565, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C9_P4_P3_1/rgb/566.png', 'id': 668426, 'video_id': 1274, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 566, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 566/566 [00:00<00:00, 386389.33it/s]
# >> annotations:
#  [{'id': 668425, 'category_id': 1, 'image_id': 668425, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 668426, 'category_id': 1, 'image_id': 668426, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2108, 'category_id': 2, 'video_id': 1274, 'frame_start': 1, 'frame_end': 318, 'label_frames': 318, 'dataset': 1}, {'id': 2109, 'category_id': 1, 'video_id': 1274, 'frame_start': 319, 'frame_end': 566, 'label_frames': 248, 'dataset': 1}]
# >> video:
#  [{'name': 'INCAR/20210521/Sessipn 2/C9_P4_P3_1/INCAR_20210521_Sessipn_2_C9_P4_P3_1_rgb.mp4', 'id': 1274, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 566, 'dataset': 1}, {'name': 'INCAR/20210521/Sessipn 2/C9_P4_P3_2/INCAR_20210521_Sessipn_2_C9_P4_P3_2_rgb.mp4', 'id': 1275, 'width': 2048, 'height': 1536, 'sensor': 'rgb', 'fps': 30, 'total_frames': 566, 'dataset': 1}]
# 100%|██████████| 566/566 [00:00<00:00, 285642.65it/s]
# >> images:
#  [{'file_name': 'INCAR/20210521/Sessipn 2/C9_P4_P3_2/rgb/565.png', 'id': 668991, 'video_id': 1275, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 565, 'date_captured': 'INCAR', 'dataset': 1}, {'file_name': 'INCAR/20210521/Sessipn 2/C9_P4_P3_2/rgb/566.png', 'id': 668992, 'video_id': 1275, 'caption': 'Sessipn 2', 'width': 2048, 'height': 1536, 'frame_index': 566, 'date_captured': 'INCAR', 'dataset': 1}]
# 100%|██████████| 566/566 [00:00<00:00, 381606.83it/s]
# >> annotations:
#  [{'id': 668991, 'category_id': 1, 'image_id': 668991, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}, {'id': 668992, 'category_id': 1, 'image_id': 668992, 'bbox': [0, 0, 2048, 1536], 'area': 3145728, 'iscrowd': 0, 'dataset': 1}]
#
# >> video_annotations:
#  [{'id': 2110, 'category_id': 2, 'video_id': 1275, 'frame_start': 1, 'frame_end': 306, 'label_frames': 306, 'dataset': 1}, {'id': 2111, 'category_id': 1, 'video_id': 1275, 'frame_start': 307, 'frame_end': 566, 'label_frames': 260, 'dataset': 1}]
# info 5
# licenses 0
# categories 2
# videos 1275
# images 668992
# tracks 0
# segment_info 0
# annotations 668992
# video_annotations 2111
# datasets 1
#
#  >> SAVING...
# JSON SAVED : /mnt/Data-Ext/Datasets/Internal Datasets/EASYRIDE/P19/INCAR/mola.json
#
# info: 5
#
# licenses: 0
#
# categories: 2
#
# videos: 1275
#
# images: 668992
#
# tracks: 0
#
# segment_info: 0
#
# annotations: 668992
#
# video_annotations: 2111
#
# datasets: 1

# %% [markdown]
# ### TESTING (OPTIONAL)
# You already have in the previous function saved a log with test results

# %%
molafile=rdir+'INCAR/'+'mola.json'
print(molafile)
molajson =  json.load(open(molafile))
for k in molajson:
    print(k, len(molajson[k]))

# %%
molafile=rdir+'INVICON/'+'mola.json'
molajson =  json.load(open(molafile))
for k in molajson:
    print(k, len(molajson[k]))

# %%
molajson["datasets"][-1]

# %%
molajson["categories"][-1]

# %%
molajson["videos"][13]

# %%
molajson["images"][0]

# %%
molajson["images"][-1]

# %%
molajson["annotations"][-1]

# %%
molajson["annotations"][0]

# %%
molajson["video_annotations"][32]

# %%
# create video ann dict {video_id_category_id: video_annotations}
videos_ann = {'%g' % x['id'] +'_'+'%g' % x['video_id'] +'_'+'%g' % x['category_id']: x for x in molajson['video_annotations']}
k_14_2=[k for k in list(videos_ann.keys()) if k.find('_14_2')>-1]
for k in k_14_2:
    display(videos_ann[k])
